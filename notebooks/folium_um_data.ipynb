# %%
import pandas as pd
import folium
from folium.plugins import FastMarkerCluster
from folium.plugins import HeatMap, FeatureGroupSubGroup
from folium.plugins import GroupedLayerControl
from folium.features import GeoJson, GeoJsonPopup
import branca.colormap as cm
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from branca.element import Template, MacroElement

# %%
folium_um_data = pd.read_csv('/Users/idsg/Desktop/Coding/daimil10/My_midterm/Midterm_Running/Data/UM_data_top_100.csv')

# %%
folium_um_data = folium_um_data.drop(columns=["Unnamed: 0"])

# %%
folium_um_data['state_code'].fillna('VA', inplace=True)
# Out:
# /var/folders/_4/_j38q0cn0kg4pnd1jf3yvymr0000gn/T/ipykernel_20299/4220867042.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   folium_um_data['state_code'].fillna('VA', inplace=True)

# %%
latitude = {'JFK 50 Mile (USA)': 39.5019,
            'American River 50 Mile Endurance Run (USA)': 38.6742,
            'Way Too Cool 50K Endurance Run (USA)': 38.7419,
            'Western States 100 Mile Endurance Run (USA)': 39.3133,
            'Rachel Carson Trail Challenge (USA)': 40.6526,
            'Leadville Trail 100 Mile (USA)': 39.2444,
            'The HAT Run 50K (USA)': 39.5763,
            'Sunmart Texas Trail Endurance Run 50 Km (USA)': 30.7283,
            'Quad Dipsea Trail Run (USA)': 37.8942,
            'Skyline 50k Endurance Run (USA)': 37.6786,
            'Bull Run Run 50 Miler (USA)': 38.7600,
            'Mountain Mist 50k (USA)': 34.7300,
            'Chuckanut 50K (USA)': 48.7033,
            'Mountain Masochist 50 Mile Trail Run (USA)': 37.5700,
            'Ice Age Trail 50 Mile Run (USA)': 42.8217,
            'Vermont 100 Mile Endurance Race (USA)': 43.6050,
            'Promise Land 50K++ (USA)': 37.2333,
            'Huff 50K Trail Run (USA)': 41.2300,
            'Squaw Peak 50 Mile Trail Run (USA)': 40.2583,
            'Wasatch Front 100 Mile (USA)': 41.0275,
            'Holiday Lake 50K++ (USA)': 37.3450,
            'NYRR Knickerbocker 60K (USA)': 40.7820,
            'Avalon Benefit 50-Mile Run (USA)': 33.3511,
            'OTHTC High Desert 50K Ultra (USA)': 35.6350,
            'McDonald Forest 50K Trail Run (USA)': 44.5760,
            'Leadville Silver Rush 50 Mile Run (USA)': 39.2444,
            'Rock/Creek StumpJump 50K (USA)': 35.0483,
            'Minnesota Voyageur Trail 50 Mile Ultra (USA)': 46.6651,
            'Rocky Raccoon 100 Mile Trail Run (USA)': 30.7283,
            'Dick Collins Firetrails 50 Mile (USA)': 37.6786,
            'Crown King Scramble 50K (USA)': 33.8544,
            'Bulldog 50k Ultra Run (USA)': 34.0683,
            'Endurance Challenge - California Trail 50 km (USA)': 37.8072,
            'Endurance Challenge - California Trail 50 Mile (USA)': 37.8200,
            'Endurance Challenge - Washington D.C. Trail 50 km (USA)': 38.9694,
            'White River 50 Mile Trail Run (USA)': 47.2525,
            'Javelina Jundred 100 Mile Endurance Run (USA)': 33.6267,
            'Strolling Jim 40 Mile (USA)': 35.5800,
            'Leona Divide 50 Mile Run (USA)': 34.7033,
            'Blues Cruise 50K Ultra Trail (USA)': 40.3340,
            'The Cowtown Marathon (USA)': 32.7510,
            'Endurance Challenge - New York Trail 50 km (USA)': 41.3133,
            'Afton Trail Run 50K (USA)': 44.9783,
            'Golden Gate Dirty 30 (USA)': 39.7700,
            'Shadow of the Giants 50K (USA)': 36.7811,
            'Vermont 50 Miles Ultra Run (USA)': 43.4510,
            'Quicksilver 50 km Endurance Run (USA)': 37.2230,
            'Bighorn Mountain Wild & Scenic 50km Trail Run (USA)': 44.8733,
            'Ohlone 50K Wilderness Run (USA)': 37.4850,
            'Miwok 100k Trail race (USA)': 37.9011,
            'Siskiyou Out Back 50 km Trail Run (USA)': 42.0544,
            'The Rut Mountain Runs (USA)': 45.2844,
            'Sylamore Trail 50k Run (USA)': 35.7917,
            'Tamalpa Headlands 50K (USA)': 37.8725,
            'Speedgoat 50k (USA)': 40.5961,
            'Moab Red Hot 55k (USA)': 38.6325,
            'McKenzie River 50 km Trail Run (USA)': 44.1230,
            'San Juan Solstice 50 Mile Run (USA)': 38.0250,
            'Chicago Lakefront Fall 50K (USA)': 41.9990,
            'Lake Sonoma 50 Mile Race (USA)': 38.6730,
            'The Bear 100 Mile Endurance Run (USA)': 41.7370,
            'Mount Cheaha 50K UltraMarathon Race (USA)': 33.9700,
            'Vermont 50 km Ultra Run (USA)': 43.4510,
            'Stone Mill 50 Mile Run (USA)': 39.1360,
            'Black Canyon Trail 100 Km Run (USA)': 34.4300,
            'Angeles Crest 100 Mile (USA)': 34.3750,
            'Ice Age Trail 50 km Run (USA)': 42.8217,
            'Umstead Endurance Run 100 Miles (USA)': 35.8200,
            'Tunnel Hill 50 Mile Race (USA)': 38.9970,
            'Catoctin 50k Trail Run (USA)': 39.6400,
            'Jed Smith Ultra Classic - 50 Km Race (USA)': 35.5647,
            'Highlands Sky 40M Trail Run (USA)': 38.8720,
            'Sunmart Texas Trail Endurance Run 50 Mile (USA)': 30.7280,
            'Noble Canyon 50k (USA)': 33.2350,
            'Hagg Lake Trail Runs 50K (USA)': 42.3520,
            'Endurance Challenge - New York Trail 50 Miles (USA)': 41.3130,
            'Terrapin Mountain 50k (USA)': 37.5550,
            'Massanutten Mountain Trails 100 Mile (USA)': 38.7900,
            'Mount Mitchell Challenge (USA)': 35.6110,
            'Le Grizz 50 Mile Ultramarathon (USA)': 48.8560,
            'Arkansas Traveller 100 (USA)': 34.8980,
            'Umstead Endurance Run 50 Miles (USA)': 35.8200,
            'Pineland Farms 50 km Trail Running (USA)': 43.9700,
            'Buckeye Trail 50k (USA)': 41.3100,
            'Endurance Challenge - Washington D.C. Trail 50 Miles (USA)': 41.3130,
            'Salem Lakeshore Frosty Fifty (USA)': 36.0700,
            'Marine Corps 50km Marathon Race (USA)': 38.8700,
            'Orcas Island 50k (USA)': 48.6500,
            'Endurance Challenge - Wisconsin Trail 50 km (USA)': 43.0630,
            'Holcomb Valley 33 Mile (USA)': 34.2600,
            'Mohican Trail 100 Mile (USA)': 40.6010,
            'Bighorn Mountain Wild & Scenic 50mi Trail Run (USA)': 44.4170,
            'Baker Lake 50K Ultra Trail Run (USA)': 48.8500,
            'Chippewa Moraine 50km Ultra Marathon (USA)': 45.0100,
            'Superior Spring 50 km Trail Race (USA)': 47.7000,
            'Trail Mix Race (USA)': 40.6100,
            'Capon Valley 50K Run (USA)': 39.3667,
            'Chicago Lakefront Spring 50K (USA)': 41.7650,
            'Hardrock Hundred Endurance Run (USA)': 37.7900,
            'Burning River 100 Mile Endurance Run (USA)': 41.1330} 

longitude = {'JFK 50 Mile (USA)': -77.6631,
             'American River 50 Mile Endurance Run (USA)': -121.1694,
             'Way Too Cool 50K Endurance Run (USA)': -120.5678,
             'Western States 100 Mile Endurance Run (USA)': -120.2300,
             'Rachel Carson Trail Challenge (USA)': -79.6998,
             'Leadville Trail 100 Mile (USA)': -106.3194,
             'The HAT Run 50K (USA)': -76.0856,
             'Sunmart Texas Trail Endurance Run 50 Km (USA)': -95.5500,
             'Quad Dipsea Trail Run (USA)': -122.5456,
             'Skyline 50k Endurance Run (USA)': -122.0883,
             'Bull Run Run 50 Miler (USA)': -77.4267,
             'Mountain Mist 50k (USA)': -86.5883,
             'Chuckanut 50K (USA)': -122.4786,
             'Mountain Masochist 50 Mile Trail Run (USA)': -79.4500,
             'Ice Age Trail 50 Mile Run (USA)': -88.6004,
             'Vermont 100 Mile Endurance Race (USA)': -72.5794,
             'Promise Land 50K++ (USA)': -79.4667,
             'Huff 50K Trail Run (USA)': -85.2283,
             'Squaw Peak 50 Mile Trail Run (USA)': -111.6458,
             'Wasatch Front 100 Mile (USA)': -111.8667,
             'Holiday Lake 50K++ (USA)': -78.8033,
             'NYRR Knickerbocker 60K (USA)': -73.9654,
             'Avalon Benefit 50-Mile Run (USA)': -118.3278,
             'OTHTC High Desert 50K Ultra (USA)': -117.6372,
             'McDonald Forest 50K Trail Run (USA)': -123.2620,
             'Leadville Silver Rush 50 Mile Run (USA)': -106.3194,
             'Rock/Creek StumpJump 50K (USA)': -85.3528,
             'Minnesota Voyageur Trail 50 Mile Ultra (USA)': -92.4227,
             'Rocky Raccoon 100 Mile Trail Run (USA)': -95.5500,
             'Dick Collins Firetrails 50 Mile (USA)': -122.0883,
             'Crown King Scramble 50K (USA)': -112.4083,
             'Bulldog 50k Ultra Run (USA)': -118.6436,
             'Endurance Challenge - California Trail 50 km (USA)': -122.4267,
             'Endurance Challenge - California Trail 50 Mile (USA)': -122.5000,
             'Endurance Challenge - Washington D.C. Trail 50 km (USA)': -77.3178,
             'White River 50 Mile Trail Run (USA)': -121.6425,
             'Javelina Jundred 100 Mile Endurance Run (USA)': -111.7375,
             'Strolling Jim 40 Mile (USA)': -86.3100,
             'Leona Divide 50 Mile Run (USA)': -118.3450,
             'Blues Cruise 50K Ultra Trail (USA)': -75.9250,
             'The Cowtown Marathon (USA)': -97.3300,
             'Endurance Challenge - New York Trail 50 km (USA)': -74.0022,
             'Afton Trail Run 50K (USA)': -92.8394,
             'Golden Gate Dirty 30 (USA)': -105.5420,
             'Shadow of the Giants 50K (USA)': -119.3528,
             'Vermont 50 Miles Ultra Run (USA)': -72.5940,
             'Quicksilver 50 km Endurance Run (USA)': -121.9390,
             'Bighorn Mountain Wild & Scenic 50km Trail Run (USA)': -107.2675,
             'Ohlone 50K Wilderness Run (USA)': -121.9390,
             'Miwok 100k Trail race (USA)': -122.6350,
             'Siskiyou Out Back 50 km Trail Run (USA)': -122.7150,
             'The Rut Mountain Runs (USA)': -111.0961,
             'Sylamore Trail 50k Run (USA)': -91.9444,
             'Tamalpa Headlands 50K (USA)': -122.5667,
             'Speedgoat 50k (USA)': -111.6533,
             'Moab Red Hot 55k (USA)': -109.5283,
             'McKenzie River 50 km Trail Run (USA)': -122.1200,
             'San Juan Solstice 50 Mile Run (USA)': -107.3133,
             'Chicago Lakefront Fall 50K (USA)': -87.6510,
             'Lake Sonoma 50 Mile Race (USA)': -122.8780,
             'The Bear 100 Mile Endurance Run (USA)': -111.8330,
             'Mount Cheaha 50K UltraMarathon Race (USA)': -85.8167,
             'Vermont 50 km Ultra Run (USA)': -72.5940,
             'Stone Mill 50 Mile Run (USA)': -77.0480,
             'Black Canyon Trail 100 Km Run (USA)': -112.7400,
             'Angeles Crest 100 Mile (USA)': -117.6250,
             'Ice Age Trail 50 km Run (USA)': -88.6004,
             'Umstead Endurance Run 100 Miles (USA)': -78.5900,
             'Tunnel Hill 50 Mile Race (USA)': -89.0430,
             'Catoctin 50k Trail Run (USA)': -77.4200,
             'Jed Smith Ultra Classic - 50 Km Race (USA)': -121.4064,
             'Highlands Sky 40M Trail Run (USA)': -79.4980,
             'Sunmart Texas Trail Endurance Run 50 Mile (USA)': -95.5500,
             'Noble Canyon 50k (USA)': -116.6010,
             'Hagg Lake Trail Runs 50K (USA)': -123.0050,
             'Endurance Challenge - New York Trail 50 Miles (USA)': -74.0020,
             'Terrapin Mountain 50k (USA)': -79.3530,
             'Massanutten Mountain Trails 100 Mile (USA)': -78.6100,
             'Mount Mitchell Challenge (USA)': -82.3170,
             'Le Grizz 50 Mile Ultramarathon (USA)': -114.2750,
             'Arkansas Traveller 100 (USA)': -92.7850,
             'Umstead Endurance Run 50 Miles (USA)': -78.5900,
             'Pineland Farms 50 km Trail Running (USA)': -70.3000,
             'Buckeye Trail 50k (USA)': -81.5990,
             'Endurance Challenge - Washington D.C. Trail 50 Miles (USA)': -74.0020,
             'Salem Lakeshore Frosty Fifty (USA)': -80.2700,
             'Marine Corps 50km Marathon Race (USA)': -77.0550,
             'Orcas Island 50k (USA)': -122.7900,
             'Endurance Challenge - Wisconsin Trail 50 km (USA)': -88.3380,
             'Holcomb Valley 33 Mile (USA)': -116.8000,
             'Mohican Trail 100 Mile (USA)': -82.2310,
             'Bighorn Mountain Wild & Scenic 50mi Trail Run (USA)': -107.2500,
             'Baker Lake 50K Ultra Trail Run (USA)': -121.7000,
             'Chippewa Moraine 50km Ultra Marathon (USA)': -91.9500,
             'Superior Spring 50 km Trail Race (USA)': -90.7500,
             'Trail Mix Race (USA)': -74.1500,
             'Capon Valley 50K Run (USA)': -78.3583,
             'Chicago Lakefront Spring 50K (USA)': -87.5750,
             'Hardrock Hundred Endurance Run (USA)': -107.6600,
             'Burning River 100 Mile Endurance Run (USA)': -81.5070}

# %%
folium_um_data['latitude'] = folium_um_data['Event name'].map(latitude)
folium_um_data['longitude'] = folium_um_data['Event name'].map(longitude)

# %%
event_coordinates = folium_um_data.groupby('Event name').first().reset_index()

# %%
average_lat = event_coordinates['latitude'].mean() 
average_lon = event_coordinates['longitude'].mean()

# %%
event_map = folium.Map(location=[average_lat, average_lon], control_scale=True, zoom_control=False, zoom_start=4)

# FastMarkerCluster(data=list(zip(event_coordinates['latitude'], event_coordinates['longitude']))).add_to(event_map)
for _, row in event_coordinates.iterrows(): 
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Event name'], 
    ).add_to(event_map)
title_html = '''
    <h3 align="center" style="font-size:20px"><b>Top 100 Ultra Marathon Events</b></h3>
    '''
event_map.get_root().html.add_child(folium.Element(title_html))
event_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7dd627f90f0e08bb0792d9c3036905ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;Top 100 Ultra Marathon Events&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7dd627f90f0e08bb0792d9c3036905ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7dd627f90f0e08bb0792d9c3036905ea = L.map(
#                 &quot;map_7dd627f90f0e08bb0792d9c3036905ea&quot;,
#                 {
#                     center: [39.353142, -98.6473],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: false,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#
#
#
#             var tile_layer_cb7a7cedb09622263fa3c9f98cafb8e5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#             var marker_7c72076b52cbae7d3090e254566587ff = L.marker(
#                 [44.9783, -92.8394],
#                 {}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#         var popup_5a7a3eabdd501ef2524554fbc32f6b70 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_451b144c80fedc3f5e84f7414513ea1a = $(`&lt;div id=&quot;html_451b144c80fedc3f5e84f7414513ea1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afton Trail Run 50K (USA)&lt;/div&gt;`)[0];
#                 popup_5a7a3eabdd501ef2524554fbc32f6b70.setContent(html_451b144c80fedc3f5e84f7414513ea1a);
#
#
#
#         marker_7c72076b52cbae7d3090e254566587ff.bindPopup(popup_5a7a3eabdd501ef2524554fbc32f6b70)
#         ;
#
#
#
#
#             var marker_dff93174f2a1b52be01aae85f7082325 = L.marker(
#                 [38.6742, -121.1694],
#                 {}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#         var popup_3b48caa5c7fed625223c0d03df48da56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_deb324074612689f1ecf2189907045c7 = $(`&lt;div id=&quot;html_deb324074612689f1ecf2189907045c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American River 50 Mile Endurance Run (USA)&lt;/div&gt;`)[0];
#                 popup_3b48caa5c7fed625223c0d03df48da56.setContent(html_deb324074612689f1ecf2189907045c7);
#
#
#
#         marker_dff93174f2a1b52be01aae85f7082325.bindPopup(popup_3b48caa5c7fed625223c0d03df48da56)
#         ;
#
#
#
#
#             var marker_4c7d09ea603284b8158dc2cd34aba8ab = L.marker(
#                 [34.375, -117.625],
#                 {}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#         var popup_2943e2caba1c4e62f1f29a5f24d64454 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f4a21778b3e76d71f6293ad857157fb = $(`&lt;div id=&quot;html_0f4a21778b3e76d71f6293ad857157fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angeles Crest 100 Mile (USA)&lt;/div&gt;`)[0];
#                 popup_2943e2caba1c4e62f1f29a5f24d64454.setContent(html_0f4a21778b3e76d71f6293ad857157fb);
#
#
#
#         marker_4c7d09ea603284b8158dc2cd34aba8ab.bindPopup(popup_2943e2caba1c4e62f1f29a5f24d64454)
#         ;
#
#
#
#
#             var marker_662b2e64bd58fe8677f889cd563fb144 = L.marker(
#                 [34.898, -92.785],
#                 {}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#         var popup_eece952ffc77881e225e43243d05b179 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e5bcd9d54b4d00019002cf9bf9347562 = $(`&lt;div id=&quot;html_e5bcd9d54b4d00019002cf9bf9347562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arkansas Traveller 100 (USA)&lt;/div&gt;`)[0];
#                 popup_eece952ffc77881e225e43243d05b179.setContent(html_e5bcd9d54b4d00019002cf9bf9347562);
#
#
#
#         marker_662b2e64bd58fe8677f889cd563fb144.bindPopup(popup_eece952ffc77881e225e43243d05b179)
#         ;
#
#
#
#
#             var marker_9dc34d242d820dd956adb903ca0548f1 = L.marker(
#                 [33.3511, -118.3278],
#                 {}
#             ).addTo(map_7dd627f90f0e08bb0792d9c3036905ea);
#
#
#         var popup_baafad793a673aaf99f5b8c1f448572d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a76722c00a66207194bc61b1e4ebacd = $(`&lt;div id=&quot;html_2a76722c00a66207194bc61b1e4ebacd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Avalon Benefit 50-Mile Run (USA)&lt;/div&gt;`)[0];
#                 popup_baafad793a673aaf99f5b8c1f448572d.setContent(html_2a76722c00a66207194b

# %%
heating_map = folium.Map(location=[39.50, -98.35], zoom_control=False, control_scale=True, zoom_start=4) 
HeatMap(data=event_coordinates[['latitude', 'longitude']].values).add_to(heating_map)
for _, row in event_coordinates.iterrows(): 
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=row['Event name']
    ).add_to(heating_map)

title_html2 = '''
    <h3 align="center" style="font-size:20px"><b>Top 100 Ultra Marathon Events Heat Map</b></h3>
    '''
heating_map.get_root().html.add_child(folium.Element(title_html2))

# %%
heating_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_296a00b02bf1275b405cf98c59798725 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;Top 100 Ultra Marathon Events Heat Map&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_296a00b02bf1275b405cf98c59798725&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_296a00b02bf1275b405cf98c59798725 = L.map(
#                 &quot;map_296a00b02bf1275b405cf98c59798725&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: false,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_296a00b02bf1275b405cf98c59798725);
#
#
#
#
#
#             var tile_layer_0f2b8b0df92b3834c29026a5fdf92cfd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_296a00b02bf1275b405cf98c59798725);
#
#
#             var heat_map_6ed6ee692bfa8f8db60f69428d1b0864 = L.heatLayer(
#                 [[44.9783, -92.8394], [38.6742, -121.1694], [34.375, -117.625], [34.898, -92.785], [33.3511, -118.3278], [48.85, -121.7], [44.8733, -107.2675], [44.417, -107.25], [34.43, -112.74], [40.334, -75.925], [41.31, -81.599], [38.76, -77.4267], [34.0683, -118.6436], [41.133, -81.507], [39.3667, -78.3583], [39.64, -77.42], [41.999, -87.651], [41.765, -87.575], [45.01, -91.95], [48.7033, -122.4786], [33.8544, -112.4083], [37.6786, -122.0883], [37.82, -122.5], [37.8072, -122.4267], [41.313, -74.002], [41.3133, -74.0022], [41.313, -74.002], [38.9694, -77.3178], [43.063, -88.338], [39.77, -105.542], [42.352, -123.005], [37.79, -107.66], [38.872, -79.498], [34.26, -116.8], [37.345, -78.8033], [41.23, -85.2283], [42.8217, -88.6004], [42.8217, -88.6004], [39.5019, -77.6631], [33.6267, -111.7375], [35.5647, -121.4064], [38.673, -122.878], [48.856, -114.275], [39.2444, -106.3194], [39.2444, -106.3194], [34.7033, -118.345], [38.87, -77.055], [38.79, -78.61], [44.576, -123.262], [44.123, -122.12], [46.6651, -92.4227], [37.9011, -122.635], [38.6325, -109.5283], [40.601, -82.231], [33.97, -85.8167], [35.611, -82.317], [37.57, -79.45], [34.73, -86.5883], [40.782, -73.9654], [33.235, -116.601], [35.635, -117.6372], [37.485, -121.939], [48.65, -122.79], [43.97, -70.3], [37.2333, -79.4667], [37.8942, -122.5456], [37.223, -121.939], [40.6526, -79.6998], [35.0483, -85.3528], [30.7283, -95.55], [36.07, -80.27], [38.025, -107.3133], [36.7811, -119.3528], [42.0544, -122.715], [37.6786, -122.0883], [40.5961, -111.6533], [40.2583, -111.6458], [39.136, -77.048], [35.58, -86.31], [30.7283, -95.55], [30.728, -95.55], [47.7, -90.75], [35.7917, -91.9444], [37.8725, -122.5667], [37.555, -79.353], [41.737, -111.833], [32.751, -97.33], [39.5763, -76.0856], [45.2844, -111.0961], [40.61, -74.15], [38.997, -89.043], [35.82, -78.59], [35.82, -78.59], [43.605, -72.5794], [43.451, -72.594], [43.451, -72.594], [41.0275, -111.8667], [38.7419, -120.5678], [39.3133, -120.23], [47.2525, -121.6425]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_296a00b02bf1275b405cf98c59798725);
#
#
#             var marker_b4e3c1b79014d6d5ae280ed9b1f09156 = L.marker(
#                 [44.9783, -92.8394],
#                 {}
#             ).addTo(map_296a00b02bf1275b405cf98c59798725);
#
#
#         var popup_5939524c276629f8f06e0e4f005c1a80 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2681779c83f26b88311d792d23c533f2 = $(`&lt;div id=&quot;html_2681779c83f26b88311d792d23c533f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afton Trail Run 50K (USA)&lt;/div&gt;`)[0];
#                 popup_5939524c276629f8f06e0e4f005c1a80.setContent(html_2681779c83f26b88311d792d23c533f2);
#
#
#
#         marker_b4e3c1b79014d6d5ae280ed9b1f09156.bindPopup(popup_5939524c276629f8f06e0e4f005c1a80)
#         ;
#
#
#
#
#             var marker_d3326a42e1db2681e57ab3cdd5de65f4 = L.marker(
#                 [38.6742, -121.1694],
#                 {}
#             ).addTo(map_296a00b02bf1275b405cf98c59798725);
#
#
#         var popup_976100ee3f3ba24122930c79add856ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_15e33d2e4244ddb4ea31a4794055226d = $(`&lt;div id=&quot;html_15e33d2e4244ddb4ea31a4794055226d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American River 50 Mile Endurance Run (USA)&lt;/div&gt;`)[0];
#                 popup_976100ee3f3ba24122930c79add856ec.setContent(html_15e33d2e4244ddb4ea31a4

# %%
choropleth_um_map = folium.Map(location=[39.50, -98.35], 
                               control_scale=True,
                               zoom_control=False, 
                               zoom_start=4) 

heat_data = [[row['latitude'], row['longitude']] for index, row in event_coordinates.reset_index().iterrows()] 
HeatMap(heat_data).add_to(choropleth_um_map)

# for _, row in event_coordinates.iterrows(): 
#     folium.Marker(
#         location=[row['latitude'], row['longitude']],
#         popup=row['Event name'], 
#     ).add_to(choropleth_um_map)

folium.Choropleth(
    geo_data='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json', 
    name='choropleth', 
    data=event_coordinates.reset_index(), 
    columns=['state_code', 'Elevation Gain (feet)', 'Event name'], 
    key_on='feature.id', 
    fill_color='PuBuGn', 
    fill_opacity=0.6, 
    line_opacity=0.2, 
    highlight=True, 
    legend_name='Elevation Gain (Feet)' 
).add_to(choropleth_um_map)

# legend_html = ''' 
# <div style=" 
#     position: fixed; bottom: 50px; right: 50px; width: 200px; height: 150px; 
#     border:2px solid grey; z-index:9999; 
#     font-size:14px; 
#     background-color: 
#     white; opacity: 0.9; 
#     padding: 10px;
#     "> 
#     <h4>Ultra Marathon Running</h4> 
#     <i class="fa fa-map-marker fa-2x" style="color:blue"></i> Event Names<br>
# </div>
# '''

# choropleth_um_map.get_root().html.add_child(folium.Element(legend_html))

# def popup_function(state_code): 
#     state_info = event_coordinates.loc[state_code] 
#     popup_content = f"<b>{state_code}</b><br>" 
#     for key, value in state_info.items(): 
#         popup_content += f"{key}: {value}<br>" 
#     return popup_content


# geojson = folium.GeoJson(
#     'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json', 
#     style_function=lambda x: {'fillColor': '#ffff00', 'color': 'black', 'weight': 2, 'dashArray': '5, 5'}, 
#     highlight_function=lambda x: {'weight': 3, 'color': 'blue'}, 
#     tooltip=folium.features.GeoJsonTooltip(fields=['name']), 
#     popup=GeoJsonPopup(fields=['name'], labels=True, localize=True) 
# ).add_to(choropleth_um_map)

# for feature in geojson.data['features']: 
#     state_code = feature['id'] 
#     event_name = feature['id']
#     if state_code in event_coordinates.index: 
#         feature['properties']['popup'] = popup_function(state_code)
    
    
# geojson.add_to(choropleth_um_map)

# %%
choropleth_um_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a208fb191fd0c190541201a061a0105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a208fb191fd0c190541201a061a0105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a208fb191fd0c190541201a061a0105 = L.map(
#                 &quot;map_0a208fb191fd0c190541201a061a0105&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: false,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0a208fb191fd0c190541201a061a0105);
#
#
#
#
#
#             var tile_layer_70d1b0d92976c64b2846c80b0be0e8c1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a208fb191fd0c190541201a061a0105);
#
#
#             var heat_map_5fb3e5f1c11da637ae1e0e4da3216d63 = L.heatLayer(
#                 [[44.9783, -92.8394], [38.6742, -121.1694], [34.375, -117.625], [34.898, -92.785], [33.3511, -118.3278], [48.85, -121.7], [44.8733, -107.2675], [44.417, -107.25], [34.43, -112.74], [40.334, -75.925], [41.31, -81.599], [38.76, -77.4267], [34.0683, -118.6436], [41.133, -81.507], [39.3667, -78.3583], [39.64, -77.42], [41.999, -87.651], [41.765, -87.575], [45.01, -91.95], [48.7033, -122.4786], [33.8544, -112.4083], [37.6786, -122.0883], [37.82, -122.5], [37.8072, -122.4267], [41.313, -74.002], [41.3133, -74.0022], [41.313, -74.002], [38.9694, -77.3178], [43.063, -88.338], [39.77, -105.542], [42.352, -123.005], [37.79, -107.66], [38.872, -79.498], [34.26, -116.8], [37.345, -78.8033], [41.23, -85.2283], [42.8217, -88.6004], [42.8217, -88.6004], [39.5019, -77.6631], [33.6267, -111.7375], [35.5647, -121.4064], [38.673, -122.878], [48.856, -114.275], [39.2444, -106.3194], [39.2444, -106.3194], [34.7033, -118.345], [38.87, -77.055], [38.79, -78.61], [44.576, -123.262], [44.123, -122.12], [46.6651, -92.4227], [37.9011, -122.635], [38.6325, -109.5283], [40.601, -82.231], [33.97, -85.8167], [35.611, -82.317], [37.57, -79.45], [34.73, -86.5883], [40.782, -73.9654], [33.235, -116.601], [35.635, -117.6372], [37.485, -121.939], [48.65, -122.79], [43.97, -70.3], [37.2333, -79.4667], [37.8942, -122.5456], [37.223, -121.939], [40.6526, -79.6998], [35.0483, -85.3528], [30.7283, -95.55], [36.07, -80.27], [38.025, -107.3133], [36.7811, -119.3528], [42.0544, -122.715], [37.6786, -122.0883], [40.5961, -111.6533], [40.2583, -111.6458], [39.136, -77.048], [35.58, -86.31], [30.7283, -95.55], [30.728, -95.55], [47.7, -90.75], [35.7917, -91.9444], [37.8725, -122.5667], [37.555, -79.353], [41.737, -111.833], [32.751, -97.33], [39.5763, -76.0856], [45.2844, -111.0961], [40.61, -74.15], [38.997, -89.043], [35.82, -78.59], [35.82, -78.59], [43.605, -72.5794], [43.451, -72.594], [43.451, -72.594], [41.0275, -111.8667], [38.7419, -120.5678], [39.3133, -120.23], [47.2525, -121.6425]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_0a208fb191fd0c190541201a061a0105);
#
#
#             var choropleth_b9422c30362606d2b9f379c5a0ed31cc = L.featureGroup(
#                 {}
#             ).addTo(map_0a208fb191fd0c190541201a061a0105);
#
#
#         function geo_json_169498d593b686b0b39a9911833ce8cf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;AL&quot;: case &quot;AZ&quot;: case &quot;IL&quot;: case &quot;MT&quot;: case &quot;OH&quot;: case &quot;PA&quot;: case &quot;WV&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d0d1e6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;AR&quot;: case &quot;IN&quot;: case &quot;ME&quot;: case &quot;MD&quot;: case &quot;MN&quot;: case &quot;NY&quot;: case &quot;NC&quot;: case &quot;OR&quot;: case &quot;TN&quot;: case &quot;TX&quot;: case &quot;WI&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f6eff7&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1c9099&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;CO&quot;: case &quot;VA&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#67a9cf&quot;, &quot;fillOpacity&quot;: 0.6,

# %%
# choropleth_um_map.save('Elevation_gain_folium.html')

# %% [markdown]
# ### Add Custom Markers

# %%
# Create a map 
m = folium.Map(location=[39.50, -98.35], zoom_start=4) 
# Add custom markers 
for lat, lon, name in zip(event_coordinates['latitude'], event_coordinates['longitude'], event_coordinates['Event name']): 
    folium.Marker( location=[lat, lon], popup=name, icon=folium.Icon(color='red', icon='info-sign') ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8f08b52bf09e355d4851d9fdca527d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8f08b52bf09e355d4851d9fdca527d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8f08b52bf09e355d4851d9fdca527d2 = L.map(
#                 &quot;map_e8f08b52bf09e355d4851d9fdca527d2&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2828923eeea3b13099c90458924fe9c6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e8f08b52bf09e355d4851d9fdca527d2);
#
#
#             var marker_514435517f2b4ec8457f162b8ae187bd = L.marker(
#                 [44.9783, -92.8394],
#                 {}
#             ).addTo(map_e8f08b52bf09e355d4851d9fdca527d2);
#
#
#             var icon_11ce1f4a313771c2d9994472b94f8a15 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_514435517f2b4ec8457f162b8ae187bd.setIcon(icon_11ce1f4a313771c2d9994472b94f8a15);
#
#
#         var popup_37eabdb213eb90add756349b7d5ac009 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ba6b256e1b28723c9f3a2e8b081b5fe = $(`&lt;div id=&quot;html_4ba6b256e1b28723c9f3a2e8b081b5fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afton Trail Run 50K (USA)&lt;/div&gt;`)[0];
#                 popup_37eabdb213eb90add756349b7d5ac009.setContent(html_4ba6b256e1b28723c9f3a2e8b081b5fe);
#
#
#
#         marker_514435517f2b4ec8457f162b8ae187bd.bindPopup(popup_37eabdb213eb90add756349b7d5ac009)
#         ;
#
#
#
#
#             var marker_e038f942531e5d1998aea6c5751f2837 = L.marker(
#                 [38.6742, -121.1694],
#                 {}
#             ).addTo(map_e8f08b52bf09e355d4851d9fdca527d2);
#
#
#             var icon_448906b980429d16351c5992046f7d97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e038f942531e5d1998aea6c5751f2837.setIcon(icon_448906b980429d16351c5992046f7d97);
#
#
#         var popup_d3607ffde1ea4d743cc079295da90121 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_159a84c5f15f2d75e32ddc11d2bf6522 = $(`&lt;div id=&quot;html_159a84c5f15f2d75e32ddc11d2bf6522&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;American River 50 Mile Endurance Run (USA)&lt;/div&gt;`)[0];
#                 popup_d3607ffde1ea4d743cc079295da90121.setContent(html_159a84c5f15f2d75e32ddc11d2bf6522);
#
#
#
#         marker_e038f942531e5d1998aea6c5751f2837.bindPopup(popup_d3607ffde1ea4d743cc079295da90121)
#         ;
#
#
#
#
#             var marker_092d5490bee476b962387ed569ac24ac = L.marker(
#                 [34.375, -117.625],
#                 {}
#             ).addTo(map_e8f08b52bf09e355d4851d9fdca527d2);
#
#
#             var icon_104b3f55fa4b83cd4b2805c738349c3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_092d5490bee476b962387ed569ac24ac.setIcon(icon_104b3f55fa4b83cd4b2805c738349c3a);
#
#
#         var popup_1582ffea9743090b9c262bc7c345d28a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_741f3c7f4f0801024ae06630143b614f = $(`&lt;div id=&quot;html_741f3c7f4f0801024ae06630143b614f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Angeles Crest 100 Mile (USA)&lt;/div&gt;`)[0];
#                 popup_1582ffea9743090b9c262bc7c345d28a.setContent(html_741f3c7f4f0801024ae06630143b614f);
#
#
#
#         marker_092d5490bee476b962387ed569ac24ac.bindPopup(popup_1582ffea9743090b9c262bc7c345d28a)
#         ;
#
#
#
#
#             var marker_349a7bd4cf6ba3cf36dd8499e1cead62 = L.marker(
#                 [34.898, -92.785],
#                 {}
#             ).addTo(map_e8f08b52bf09e355d4851d9fdca527d2);
#
#
#             var icon_e63edd31e3a148b71e452fcd1b9a2e49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quo

# %%
mult_map = folium.Map(location=[39.50, -98.35], zoom_control=True, control_scale=True, zoom_start=4)

unique_colors = [
    '#FF0000', '#00FF00', '#0000FF', '#FFFF00', '#FF00FF', '#00FFFF', '#800000', '#008000', '#000080', '#808000', '#800080', '#008080'
]

color_dict = {distance: unique_colors[i % len(unique_colors)] for i, distance in enumerate(event_coordinates['Distance (miles)'].unique())}


feature_groups = {}
heat_map_layers = {}
distances = event_coordinates['Distance (miles)'].unique()

for distance in distances:
    # Create feature groups for each distance
    feature_groups[distance] = folium.FeatureGroup(name=f'Distance = {distance}')
    
    # Create heat map layers for each distance
    heat_data = event_coordinates[event_coordinates['Distance (miles)'] == distance][['latitude', 'longitude']].values.tolist()
    heat_map_layers[distance] = folium.FeatureGroup(name=f'Heat Map for {distance} miles')

    heat_map_layer = HeatMap(heat_data)
    heat_map_layer.add_to(heat_map_layers[distance])

    # Add markers to feature groups
    for i in range(len(event_coordinates['latitude'])):
        if event_coordinates['Distance (miles)'][i] == distance:
            color_hex = color_dict[distance]
            popup_text = f"Name: {event_coordinates['Event name'][i]}<br>Elevation Gain: {event_coordinates['Elevation Gain (feet)'][i]}<br>Distance: {distance}"
            marker = folium.Marker(
                location=[event_coordinates['latitude'][i], event_coordinates['longitude'][i]],
                popup=folium.Popup(popup_text, max_width=300),
                icon=folium.Icon(icon_color=color_hex)
            )
            feature_groups[distance].add_child(marker)

# Add feature groups and heat map layers to map
for distance in distances:
    mult_map.add_child(feature_groups[distance])
    mult_map.add_child(heat_map_layers[distance])


all_heat_data = event_coordinates[['latitude', 'longitude']].values.tolist()

overall_heat_map = HeatMap(all_heat_data, name='Overall Heat Map')

overall_heat_map.add_to(mult_map)

# Create choropleth layer
ch_elevation_gain = folium.Choropleth(
    geo_data='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/us-states.json', 
    name='Avg Elevation Gain', 
    data=event_coordinates.reset_index(), 
    columns=['state_code', 'Elevation Gain (feet)'], 
    key_on='feature.id', 
    fill_color='PuBuGn', 
    fill_opacity=0.6, 
    line_opacity=0.2, 
    highlight=True, 
    legend_name='Elevation Gain (Feet)' 
).add_to(mult_map)

# Define the groupings for the layers
grouped_layers = {
    'Distances': list(feature_groups.values()),
    'Heat Maps': list(heat_map_layers.values()) + [overall_heat_map],
}

# Add GroupedLayerControl to the map
GroupedLayerControl(
    groups=grouped_layers,
    exclusive_groups=False,
    collapsed=True,
).add_to(mult_map)

folium.LayerControl(collapsed=True).add_to(mult_map)



distance_counts = event_coordinates['Distance (miles)'].value_counts().sort_index()

legend_html = '''
<div id="legend" style="position: fixed; bottom: 50px; right: 50px; width: 200px; height: auto; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; opacity: 0.9; padding: 10px; display: block;">
    <h4>Distance (miles)</h4>
'''
for distance, count in distance_counts.items():
    color_hex = color_dict[distance]
    legend_html += f'<i style="background-color: {color_hex}; color: white; width: 15px; height: 15px; display: inline-block;">&nbsp;</i> {distance} miles ({count} event(s))<br>'

legend_html += '''
</div>
<button onclick="toggleLegend()" style="position: fixed; bottom: 10px; right: 10px; z-index:9999; background-color:grey; color: white; border:none; padding: 5px; cursor: pointer;">Toggle Legend</button>
<script>
    function toggleLegend() {
        var legend = document.getElementById('legend');
        if (legend.style.display === 'none') {
            legend.style.display = 'block';
        } else {
            legend.style.display = 'none';
        }
    }
</script>
'''

mult_map.get_root().html.add_child(folium.Element(legend_html))

# %%
mult_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21abed2ecea6b89963140dd88d4a32ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div id=&quot;legend&quot; style=&quot;position: fixed; bottom: 50px; right: 50px; width: 200px; height: auto; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; opacity: 0.9; padding: 10px; display: block;&quot;&gt;
#     &lt;h4&gt;Distance (miles)&lt;/h4&gt;
# &lt;i style=&quot;background-color: #008080; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 26.2 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #808000; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 28.4 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #800000; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 30.0 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #FF0000; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 31.0 miles (50 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #00FFFF; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 33.0 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #008000; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 34.1 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #800080; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 36.0 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #000080; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 37.3 miles (1 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #FF00FF; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 40.0 miles (3 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #00FF00; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 50.0 miles (24 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #FFFF00; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 62.0 miles (2 event(s))&lt;br&gt;&lt;i style=&quot;background-color: #0000FF; color: white; width: 15px; height: 15px; display: inline-block;&quot;&gt;&amp;nbsp;&lt;/i&gt; 100.0 miles (14 event(s))&lt;br&gt;
# &lt;/div&gt;
# &lt;button onclick=&quot;toggleLegend()&quot; style=&quot;position: fixed; bottom: 10px; right: 10px; z-index:9999; background-color:grey; color: white; border:none; padding: 5px; cursor: pointer;&quot;&gt;Toggle Legend&lt;/button&gt;
# &lt;script&gt;
#     function toggleLegend() {
#         var legend = document.getElementById(&#x27;legend&#x27;);
#         if (legend.style.display === &#x27;none&#x27;) {
#             legend.style.display = &#x27;block&#x27;;
#         } else {
#             legend.style.display = &#x27;none&#x27;;
#         }
#     }
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21abed2ecea6b89963140dd88d4a32ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21abed2ecea6b89963140dd88d4a32ae = L.map(
#                 &quot;map_21abed2ecea6b89963140dd88d4a32ae&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_21abed2ecea6b89963140dd88d4a32ae);
#
#
#
#
#
#             var tile_layer_afc7e1c175fb605b9d237d7b97f58807 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21abed2ecea6b89963140dd88d4a32ae);
#
#
#             var feature_group_8ebf97321e3cf965fc3bf9917bdb0481 = L.featureGroup(
#                 {}
#             ).addTo(map_21abed2ecea6b89963140dd88d4a32ae);
#
#
#             var marker_906da458907e213e56b6689ac07f937e = L.marker(
#                 [44.9783, -92.8394],
#                 {}
#             ).addTo(feature_group_8ebf97321e3cf965fc3bf9917bdb0481);
#
#
#             var icon_f0280937aec31ac370818d08d337cc3d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quo

# %%
new_terrain_map = folium.Map()

new_terrain_map = folium.Map(location=[39.50, -98.35], zoom_start=4, tiles='https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png', attr='OpenTopoMap')
# Create heat map data with weights

# Create overall heat map data without weights
heat_data_terrain = event_coordinates[['latitude', 'longitude']].values.tolist()

# Create overall heat map layer without weights
overall_heat_map_terrain = HeatMap(heat_data_terrain, name='Overall Heat Map')

# Add the overall heat map layer to the map
overall_heat_map_terrain.add_to(new_terrain_map)

folium.LayerControl(collapsed=True).add_to(new_terrain_map)

title_html3 = '''
    <h3 align="center" style="font-size:20px"><b>Top 100 Ultra Marathon Events Heat Map</b></h3>
    '''
overall_heat_map_terrain.get_root().html.add_child(folium.Element(title_html3))

# Show the map
new_terrain_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e0917adacdde63f6474c43dbce96b1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;&lt;b&gt;Top 100 Ultra Marathon Events Heat Map&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e0917adacdde63f6474c43dbce96b1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e0917adacdde63f6474c43dbce96b1a = L.map(
#                 &quot;map_9e0917adacdde63f6474c43dbce96b1a&quot;,
#                 {
#                     center: [39.5, -98.35],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8f2632cde6ac35a3096379b5e82bccb = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e0917adacdde63f6474c43dbce96b1a);
#
#
#             var heat_map_cb3495e60ffb193799db57c9d008aca4 = L.heatLayer(
#                 [[44.9783, -92.8394], [38.6742, -121.1694], [34.375, -117.625], [34.898, -92.785], [33.3511, -118.3278], [48.85, -121.7], [44.8733, -107.2675], [44.417, -107.25], [34.43, -112.74], [40.334, -75.925], [41.31, -81.599], [38.76, -77.4267], [34.0683, -118.6436], [41.133, -81.507], [39.3667, -78.3583], [39.64, -77.42], [41.999, -87.651], [41.765, -87.575], [45.01, -91.95], [48.7033, -122.4786], [33.8544, -112.4083], [37.6786, -122.0883], [37.82, -122.5], [37.8072, -122.4267], [41.313, -74.002], [41.3133, -74.0022], [41.313, -74.002], [38.9694, -77.3178], [43.063, -88.338], [39.77, -105.542], [42.352, -123.005], [37.79, -107.66], [38.872, -79.498], [34.26, -116.8], [37.345, -78.8033], [41.23, -85.2283], [42.8217, -88.6004], [42.8217, -88.6004], [39.5019, -77.6631], [33.6267, -111.7375], [35.5647, -121.4064], [38.673, -122.878], [48.856, -114.275], [39.2444, -106.3194], [39.2444, -106.3194], [34.7033, -118.345], [38.87, -77.055], [38.79, -78.61], [44.576, -123.262], [44.123, -122.12], [46.6651, -92.4227], [37.9011, -122.635], [38.6325, -109.5283], [40.601, -82.231], [33.97, -85.8167], [35.611, -82.317], [37.57, -79.45], [34.73, -86.5883], [40.782, -73.9654], [33.235, -116.601], [35.635, -117.6372], [37.485, -121.939], [48.65, -122.79], [43.97, -70.3], [37.2333, -79.4667], [37.8942, -122.5456], [37.223, -121.939], [40.6526, -79.6998], [35.0483, -85.3528], [30.7283, -95.55], [36.07, -80.27], [38.025, -107.3133], [36.7811, -119.3528], [42.0544, -122.715], [37.6786, -122.0883], [40.5961, -111.6533], [40.2583, -111.6458], [39.136, -77.048], [35.58, -86.31], [30.7283, -95.55], [30.728, -95.55], [47.7, -90.75], [35.7917, -91.9444], [37.8725, -122.5667], [37.555, -79.353], [41.737, -111.833], [32.751, -97.33], [39.5763, -76.0856], [45.2844, -111.0961], [40.61, -74.15], [38.997, -89.043], [35.82, -78.59], [35.82, -78.59], [43.605, -72.5794], [43.451, -72.594], [43.451, -72.594], [41.0275, -111.8667], [38.7419, -120.5678], [39.3133, -120.23], [47.2525, -121.6425]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_9e0917adacdde63f6474c43dbce96b1a);
#
#
#             var layer_control_f3684c9e6179b9f8b1c93ebd114ea74c = {
#                 base_layers : {
#                     &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot; : tile_layer_f8f2632cde6ac35a3096379b5e82bccb,
#                 },
#                 overlays :  {
#                     &quot;Overall Heat Map&quot; : heat_map_cb3495e60ffb193799db57c9d008aca4,
#                 },
#             };
#             L.control.layers(
#                 layer_control_f3684c9e6179b9f8b1c93ebd114ea74c.base_layers,
#                 layer_control_f3684c9e6179b9f8b1c93ebd114ea74c.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_9e0917adacdde63f6474c43dbce96b1a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create DataFrame with checkpoints and their coordinates
western_states_100_race_line = {
    'Checkpoint': ['Start', 'Lyon Ridge', 'Red Star Ridge', 'Duncan Canyon', 'Robinson Flat', 'Miller’s Defeat', 'Michigan Bluff', 'Foresthill', 'Rucky Chucky', 'No Hands Bridge', 'Brown’s Bar', 'Canyon Way', 'Finish'],
    'Latitude1': [39.2098, 39.2600, 39.2748, 39.2684, 39.2982, 39.3265, 39.3799, 39.4038, 39.2704, 39.0292, 39.3311, 38.9103, 38.9098],
    'Longitude2': [-120.2269, -120.4683, -120.4336, -120.5142, -120.5111, -120.5830, -120.7133, -120.8197, -120.8919, -121.0702, -120.9690, -121.0744, -121.0502]
}
checkpoints_df = pd.DataFrame(western_states_100_race_line)

# %%
western_states_map = folium.Map(location=[39.2098, -120.2269], zoom_start=8, tiles='https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png', attr='OpenTopoMap')

# Add markers to the map
for idx, row in checkpoints_df.iterrows():
    folium.Marker(
        location=[row['Latitude1'], row['Longitude2']],
        popup=row['Checkpoint'],
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(western_states_map)

# Add lines connecting the checkpoints
coordinates = list(zip(checkpoints_df['Latitude1'], checkpoints_df['Longitude2']))
folium.PolyLine(locations=coordinates, color='blue').add_to(western_states_map)


# Add Layer Control
folium.LayerControl().add_to(western_states_map)

# Display the map
western_states_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f4612478550d896680734b3d22ce9ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f4612478550d896680734b3d22ce9ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f4612478550d896680734b3d22ce9ad = L.map(
#                 &quot;map_2f4612478550d896680734b3d22ce9ad&quot;,
#                 {
#                     center: [39.2098, -120.2269],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42f986b5ed1433c0ce08aec1fdea5548 = L.tileLayer(
#                 &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;OpenTopoMap&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2f4612478550d896680734b3d22ce9ad);
#
#
#             var marker_1b1bcb4806d006e6f6d59d97a6f72e68 = L.marker(
#                 [39.2098, -120.2269],
#                 {}
#             ).addTo(map_2f4612478550d896680734b3d22ce9ad);
#
#
#             var icon_ca6b4212770b0f3d500b1f0b0e0cdf09 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1b1bcb4806d006e6f6d59d97a6f72e68.setIcon(icon_ca6b4212770b0f3d500b1f0b0e0cdf09);
#
#
#         var popup_3bfb6a13319d92a8997bc967286240aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96c5ad159dd291a4e4b3d118a01b4f36 = $(`&lt;div id=&quot;html_96c5ad159dd291a4e4b3d118a01b4f36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Start&lt;/div&gt;`)[0];
#                 popup_3bfb6a13319d92a8997bc967286240aa.setContent(html_96c5ad159dd291a4e4b3d118a01b4f36);
#
#
#
#         marker_1b1bcb4806d006e6f6d59d97a6f72e68.bindPopup(popup_3bfb6a13319d92a8997bc967286240aa)
#         ;
#
#
#
#
#             var marker_da28164757703e10d453799dfd8cb51c = L.marker(
#                 [39.26, -120.4683],
#                 {}
#             ).addTo(map_2f4612478550d896680734b3d22ce9ad);
#
#
#             var icon_220faf496c7de3bdffcb0b937452a170 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_da28164757703e10d453799dfd8cb51c.setIcon(icon_220faf496c7de3bdffcb0b937452a170);
#
#
#         var popup_491be6a17f342095a190cc9a520c3ebe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09813ec37dca9bcc4eb9427f26e268f5 = $(`&lt;div id=&quot;html_09813ec37dca9bcc4eb9427f26e268f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lyon Ridge&lt;/div&gt;`)[0];
#                 popup_491be6a17f342095a190cc9a520c3ebe.setContent(html_09813ec37dca9bcc4eb9427f26e268f5);
#
#
#
#         marker_da28164757703e10d453799dfd8cb51c.bindPopup(popup_491be6a17f342095a190cc9a520c3ebe)
#         ;
#
#
#
#
#             var marker_c508f87a54f06ae861da0258c96cbb7d = L.marker(
#                 [39.2748, -120.4336],
#                 {}
#             ).addTo(map_2f4612478550d896680734b3d22ce9ad);
#
#
#             var icon_9c443d8dceb7ae150105074d90e416b8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c508f87a54f06ae861da0258c96cbb7d.setIcon(icon_9c443d8dceb7ae150105074d90e416b8);
#
#
#         var popup_c690ceb1a6893bf6380c5175aa4e5827 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d95e783668ed8478282e9db24dd15225 = $(`&lt;div id=&quot;html_d95e783668ed8478282e9db24dd15225&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Red Star Ridge&lt;/div&gt;`)[0];
#                 popup_c690ceb1a6893bf6380c5175aa4e5827.setContent(html_d95e783668ed8478282e9db24dd15225);
#
#
#
#         marker_c508f87a54f06ae861da0258c96cbb7d.bindPopup(popup_c690ceb1a6893bf6380c5175aa4e5827)
#         ;
#
#
#
#
#             var marker_56cc8b6ebbcccb3a0baa5a5da5ed7e65 = L.marker(
#                 [39.2684, -120.5142],
#                 {}
#             ).addTo(map_2f4612478550d896680734b3d22ce9ad);
#
#
#             var icon_c83c419a8f3db8d21023b8741d210b75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_56cc8b6ebbcccb3a0baa5a5da5ed7e65.setIcon(icon_c83c419a8f3db8d21023b8741d210b75);
